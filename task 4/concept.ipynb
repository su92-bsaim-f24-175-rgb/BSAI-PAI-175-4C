# %%
n = 6
for i in range(n):
    for j in range(n):
        if i == 0 or i == n-1 or j == 0 or j == n-1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
print()

for i in range(n):
    for j in range(n):
        if (i == 0 or i == n-1 or      
            j == 0 or j == n-1 or      
            i == j):                  
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()

print()

for i in range(n):
    for j in range(n):
        if (i == 0 or i == n-1 or      
            j == 0 or j == n-1 or      
            j == n-i-1):              
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()


for i in range(n):
    for j in range(n):
        if (i == 0 or i == n-1 or
            j == 0 or j == n-1 or
            (i == 2 or i == 3) and j < 4):
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
print()
for i in range(6):
    for j in range(6):
        if i == 0 or i == 5 or j == 0 or j == 5 or (i == 2 and j == 2) or (i == 3 and j == 3) or (i == 2 and j == 3) or (i == 3 and j == 2) or (i == 1 and j == 4) or (i == 4 and j == 1) or (i == 1 and j == 1) or (i == 4 and j == 4):
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
for i in range(n):
    for j in range(n):
        if (i == 0 or i == n-1 or
            j == 0 or j == n-1 or
            (i == 2 or i == 3) and (j == 2 or j == 3)):
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
# Out:
# * * * * * *
# *         *
# *         *
# *         *
# *         *
# * * * * * *
#
# * * * * * *
# * *       *
# *   *     *
# *     *   *
# *       * *
# * * * * * *
#
# * * * * * *
# *       * *
# *     *   *
# *   *     *
# * *       *
# * * * * * *
# * * * * * *
# *         *
# * * * *   *
# * * * *   *
# *         *
# * * * * * *
#
# * * * * * *
# * *     * *
# *   * *   *
# *   * *   *
# * *     * *
# * * * * * *
# * * * * * *
# *         *
# *   * *   *
# *   * *   *
# *         *
# * * * * * *
